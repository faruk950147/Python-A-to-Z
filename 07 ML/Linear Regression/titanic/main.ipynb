# %%
from tokenize import Ignore
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# 1. load data
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# 2. drop unnecessary columns
df.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'], inplace=True, errors='ignore')

# 3. fill missing values
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Fare'] = df['Fare'].fillna(df['Fare'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# check duplicates & remove
df.drop_duplicates(inplace=True)
print("Shape after removing duplicates:", df.shape)

# 4. convert categorical variables
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
df['Embarked'] = df['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})

# 5. Remove outliers
Q1 = df[['Age', 'Fare']].quantile(0.25)
Q3 = df[['Age', 'Fare']].quantile(0.75)

IQR = Q3 - Q1

mask = (
    (df[['Age', 'Fare']] >= (Q1 - 1.5 * IQR)) &
    (df[['Age', 'Fare']] <= (Q3 + 1.5 * IQR))
).all(axis=1)

df = df[mask]

print("Shape after removing outliers:", df.shape)
# Out:
# Shape after removing duplicates: (775, 8)
# Shape after removing outliers: (651, 8)
