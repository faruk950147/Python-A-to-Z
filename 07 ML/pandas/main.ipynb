# %%
import pandas as pd

data = pd.Series(range(10))
data.index = [f'row {i}' for i in range(10)]

df = pd.DataFrame(data, columns=['column-1'])
df['column-2'] = df['column-1'] ** 2
df
# Out:
#        column-1  column-2
# row 0         0         0
# row 1         1         1
# row 2         2         4
# row 3         3         9
# row 4         4        16
# row 5         5        25
# row 6         6        36
# row 7         7        49
# row 8         8        64
# row 9         9        81
