# %%
import pandas as pd
s = pd.Series([1, 2, 3, 4, 5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Simple definition of a pandas DataFrame with some sample data.
import pandas as pd
data = pd.Series([1, 2, 3, 4, 5, 'six', 'seven'])

# data.dtype # data type of the Series
# data.values # the underlying numpy array of the Series
# data.index # the index of the Series
# indexing
# data[0] # access the first element of the Series
# data[1:4] # access a slice of the Series from index 1 to index 3 (exclusive)
# data[-1] # access the last element of the Series
# data[-3:] # access the last three elements of the Series
# data[:3] # access the first three elements of the Series
# data[::2] # access every other element of the Series starting from index 0  
    

# functions to explore the data
data.loc
data.iloc[0] # access the first element of the Series using integer location
data.iloc[[1,2,3]] # access a slice of the Series from index 1 to index 3 (exclusive) using integer location

# data.shape # returns the shape of the data (number of rows and columns)
# data.info() # provides information about the data, including the data type and number of non-null values
# data.head() # shows the first few rows of the data
# data.tail() # shows the last few rows of the data
# data.describe() # provides summary statistics of the data
# data.value_counts() # counts the unique values in the data
# data.isnull() # checks for missing values in the data
# data.isna() # checks for missing values in the data
# data.notnull() # checks for non-missing values in the data
# data.notna() # checks for non-missing values in the data
# data.dropna() # drops the missing values from the data
# data.fillna(0) # fills the missing values with a specified value (0 in this case)
# data.astype(str) # converts the data to a specified type (string in this case)
# data.str.upper() # converts the string data to uppercase
# data.str.lower() # converts the string data to lowercase
# data.str.contains('s') # checks if the string data contains a specified substring ('s' in this case)
# data.str.replace('s', 'S') # replaces a specified substring ('s') with another substring ('S') in the string data
# data.str.len() # returns the length of each string in the data
# data.str.split() # splits the string data into a list of substrings based on whitespace
# data.str.split(',') # splits the string data into a list of substrings based on a specified delimiter (',' in this case)
# data.str.split(',', expand=True) # splits the string data into separate columns based on a specified delimiter (',' in this case) and expands the result into a
# Out:
# 1    2
# 2    3
# 3    4
# dtype: object
