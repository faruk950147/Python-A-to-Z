# %%
import pandas as pd
s = pd.Series([1, 2, 3, 4, 5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Simple definition of a pandas DataFrame with some sample data.
import pandas as pd
data = pd.Series([1, 2, 3, 4, 5, 'six', 'seven'])

data.dtype
# data.values
# data.index
# Out:
# dtype('O')
