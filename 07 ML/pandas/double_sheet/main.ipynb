# %%
import pandas as pd
df = pd.read_excel('data1.xlsx', sheet_name=['Sheet1', 'Sheet2'])
df
# Out:
# {'Sheet1':     SL NAME  AGE
#  0  101    A   15
#  1  102    B   16
#  2  103    C   17
#  3  104    D   18
#  4  105    E   19
#  5  106    F   20,
#  'Sheet2':     ID  PERFORMANCE
#  0    1           80
#  1    2           81
#  2    3           82
#  3    4           83
#  4    5           84
#  5    6           85
#  6    7           86
#  7    8           87
#  8    9           88
#  9   10           89
#  10  11           90
#  11  12           91
#  12  13           92
#  13  14           93}
