# %%
import pandas as pd

data = {
"name": ["John", "Smith", "Alice"],
    "age": [30, 25, 28],
    "city": ["New York", "Los Angeles", "Chicago"]
}

df = pd.DataFrame(data)

print(df.to_string(index=False))
# Out:
#  name  age        city
#  John   30    New York
# Smith   25 Los Angeles
# Alice   28     Chicago
