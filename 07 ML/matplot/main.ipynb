# %% [markdown]
# Matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("../dataset/company_data_1_year.csv")
clean_df = df.info()
print(clean_df)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Employee_ID       60 non-null     str
#  1   Employee_Name     60 non-null     str
#  2   Department        60 non-null     str
#  3   Position          60 non-null     str
#  4   Salary_Per_Month  60 non-null     int64
#  5   Month             60 non-null     str
#  6   Sales_Amount      60 non-null     int64
#  7   Bonus             60 non-null     float64
# dtypes: float64(1), int64(2), str(5)
# memory usage: 3.9 KB
# None
