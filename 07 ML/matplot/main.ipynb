# %% [markdown]
# matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("../dataset/company_data_1_year.csv")

df
# Out:
#         ID           Name Department           Position  Salary      Month  \
# 0   EMP001       John Doe      Sales    Sales Executive   30000    January
# 1   EMP002     Jane Smith  Marketing  Marketing Manager   45000    January
# 2   EMP003  Michael Brown         IT  Software Engineer   50000    January
# 3   EMP004    Emily Davis      Sales    Sales Executive   32000    January
# 4   EMP005  Robert Wilson         HR         HR Manager   40000    January
# 5   EMP001       John Doe      Sales    Sales Executive   30000   February
# 6   EMP002     Jane Smith  Marketing  Marketing Manager   45000   February
# 7   EMP003  Michael Brown         IT  Software Engineer   50000   February
# 8   EMP004    Emily Davis      Sales    Sales Executive   32000   February
# 9   EMP005  Robert Wilson         HR         HR Manager   40000   February
# 10  EMP001       John Doe      Sales    Sales Executive   30000      March
# ...
