# %% [markdown]
# Matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("../dataset/company_data_1_year.csv")
clean_df = df.describe()
print(clean_df.to_string(index=False))
# Out:
#  Salary_Per_Month  Sales_Amount       Bonus
#         60.000000     60.000000   60.000000
#      39400.000000  79045.950000 3671.307667
#       7642.876378  66236.867794 3082.654538
#      30000.000000      0.000000    0.000000
#      32000.000000      0.000000    0.000000
#      40000.000000 111070.500000 5395.800000
#      45000.000000 138674.500000 6215.190000
#      50000.000000 157466.000000 7435.950000
