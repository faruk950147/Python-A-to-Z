# %%
import pandas as pd

# CSV loading
df = pd.read_csv('dataset/titanic.csv')

# Drop unnecessary columns
df.drop(columns=['PassengerId', 'Cabin', 'Ticket'], inplace=True)

# Fill missing values
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# Extract Title from Name
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# Lump rare titles into 'Rare' and normalize some
df['Title'] = df['Title'].replace(['Lady', 'Countess','Capt','Col','Don','Dr','Major','Rev','Sir','Jonkheer','Dona'], 'Rare')
df['Title'] = df['Title'].replace('Mlle', 'Miss')
df['Title'] = df['Title'].replace('Ms', 'Miss')
df['Title'] = df['Title'].replace('Mme', 'Mrs')

# Encode Title numerically
df['Title'] = df['Title'].map({'Mr':0, 'Miss':1, 'Mrs':2, 'Master':3, 'Rare':4})

# Encode Sex
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

# Encode Embarked
df['Embarked'] = df['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})
df = pd.get_dummies(df, columns=['Embarked'], drop_first=True)

# Drop Name column (optional)
df.drop(columns=['Name'], inplace=True)

# Check missing values & info
print("Missing values after cleaning:")
print(df.isnull().sum())
print("\nDataFrame info:")
print(df.info())

# Optional: Save cleaned CSV
df.to_csv('titanic_cleaned.csv', index=False)
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\.'
# <>:14: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\Omar Faruk\AppData\Local\Temp\ipykernel_440\4074751462.py:14: SyntaxWarning: invalid escape sequence '\.'
#   df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
# Missing values after cleaning:
# Survived      0
# Pclass        0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Title         0
# Embarked_1    0
# Embarked_2    0
# dtype: int64
#
# DataFrame info:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    int64
#  2   Sex         891 non-null    int64
#  3   Age         891 non-null    float64
#  4   SibSp       891 non-null    int64
#  5   Parch       891 non-null    int64
#  6   Fare        891 non-null    float64
#  7   Title       891 non-null    int64
#  8   Embarked_1  891 non-null    bool
#  9   Embarked_2  891 non-null    bool
# dtypes: bool(2), float64(2), int64(6)
# memory usage: 57.6 KB
# None
