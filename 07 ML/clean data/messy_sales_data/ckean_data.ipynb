# %%
import pandas as pd

# Correct way to load a CSV file
df = pd.read_csv('messy_sales_data_cleaned.csv')

# Optional: see the first few rows
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21745 entries, 0 to 21744
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        21745 non-null  str
#  1   Customer Name   21745 non-null  str
#  2   Product         21745 non-null  str
#  3   Category        21745 non-null  str
#  4   Quantity        21745 non-null  float64
#  5   Unit Price      21745 non-null  float64
#  6   Total Amount    21745 non-null  float64
#  7   Order Date      21745 non-null  str
#  8   City            21745 non-null  str
#  9   Payment Method  21745 non-null  str
#  10  Status          21745 non-null  str
# dtypes: float64(3), str(8)
# memory usage: 1.8 MB
# None
