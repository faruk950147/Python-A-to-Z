# %%
import pandas as pd
df = pd.read_csv("messy_customer_sales_data.csv")
df
# Out:
#     Customer            Email        Amount           Date
# 0      karim              NaN           700            NaN
# 1        NaN  rahim@gmail.com           500  March 1, 2025
# 2      SALMA  rahim@gmail.com  One Thousand     2025/03/01
# 3      SALMA  karim@gmail.com           800            NaN
# 4     nabila  rahim@gmail.com           NaN     2025/03/01
# ..       ...              ...           ...            ...
# 995    SALMA              NaN           800     01-03-2025
# 996   Jamal   karim@gmail.com           700            NaN
# 997   nabila  salma@gmail.com           500     01-03-2025
# 998    SALMA  karim@gmail.com           700            NaN
# 999     RAFI              NaN          1200     2025/03/01
#
# [1000 rows x 4 columns]
