# %%
import pandas as pd

df = pd.read_csv('train.csv')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10000 non-null  int64
#  1   Age         10000 non-null  int64
#  2   Name        9503 non-null   str
#  3   Email       10000 non-null  str
#  4   Product     10000 non-null  str
#  5   Category    10000 non-null  str
#  6   Quantity    9788 non-null   float64
#  7   Unit Price  10000 non-null  int64
#  8   Total       10000 non-null  int64
#  9   Payment     10000 non-null  str
#  10  Ordered At  9006 non-null   str
# dtypes: float64(1), int64(4), str(6)
# memory usage: 859.5 KB
