# %%
import pandas as pd

df = pd.read_csv('../dataset/massy_customer_sales_data.csv')
df
# Out:
#       Customer_ID  Age     Customer_Name                          Email  \
# 0               1   25    Frances Newton       heatherscott@example.net
# 1               2   25    Chelsea Romero  christopherbrooks@example.org
# 2               3   55               NaN             anne99@example.com
# 3               4   57        Austin Ray   hamiltonbenjamin@example.net
# 4               5   58  Christopher Hall           rachel09@example.net
# ...           ...  ...               ...                            ...
# 9995         9996   36         Ryan Gill              shaas@example.org
# 9996         9997   48        Justin Ali             juan16@example.net
# 9997         9998   39    Jessica Kramer           monica92@example.net
# 9998         9999   64    Lucas Espinoza        rosalesmary@example.org
# 9999        10000   55    Jeffery Martin       walshkristen@example.net
#
#       Ordered_At     Product     Category  Quantity  Unit_Price  Total  \
# ...
