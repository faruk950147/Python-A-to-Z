# %%
import pandas as pd

df = pd.read_csv('../dataset/massy_customer_sales_data.csv')
df
# Out:
#    Customer_ID     Customer_Name                         Email  Ordered_At  \
# 0         C001        Omar Faruk           omarfaruk@gmail.com   12/5/2025
# 1         C002  Annette Anderson  christianangela@johnston.com   1/18/2026
# 2         C003       Angel Scott           kjennings@gmail.com   1/23/2026
# 3         C004     Julie Freeman             vlittle@yahoo.com    3/5/2025
# 4         C005      MEGAN MARTIN             james95@riley.net   8/19/2025
# ..         ...               ...                           ...         ...
# 95        C096  Heather Williams        parkerkendra@gmail.com  12/14/2025
# 96        C097     Jason Jimenez        michelleevans@king.org   9/18/2025
# 97        C098      Pamela Hayes   claudia26@lewis-hartman.net   3/18/2025
# 98        C099   Nicholas Duncan           allison27@gmail.com  10/17/2025
# 99        C100      Judith Rojas         jennafoster@stone.org    8/9/2025
#
#          Product     Category  Quantity  Unit_Price  Total Payment
# ...
