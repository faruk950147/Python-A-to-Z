# %%
import pandas as pd

df = pd.read_csv('../dataset/massy_customer_sales_data.csv')

df.head()
# Out:
#    ID  Age              Name                          Email     Product  \
# 0   1   25    Frances Newton       heatherscott@example.net  Smartphone
# 1   2   25    Chelsea Romero  christopherbrooks@example.org      Webcam
# 2   3   55               NaN             anne99@example.com  Headphones
# 3   4   57        Austin Ray   hamiltonbenjamin@example.net    Keyboard
# 4   5   58  Christopher Hall           rachel09@example.net     Speaker
#
#       Category  Quantity  Unit Price  Total Payment  Ordered At
# 0  Photography       4.0        1498   5992  PayPal  2025-03-30
# 1  Photography       3.0         592   1776    Cash  2025-10-04
# 2  Accessories       NaN         252      0  PayPal  2025-02-18
# 3  Electronics       1.0         485    485    Cash         NaN
# 4  Electronics       4.0         896   3584  PayPal  2025-10-25
