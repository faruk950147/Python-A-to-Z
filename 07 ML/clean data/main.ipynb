# %%
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\.'
# <>:14: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\Omar Faruk\AppData\Local\Temp\ipykernel_2368\2642720877.py:14: SyntaxWarning: invalid escape sequence '\.'
#   df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
