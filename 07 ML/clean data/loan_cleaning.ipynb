# %%
import pandas as pd
df = pd.read_csv("dataset/loan.csv")


# Check the null values
# df.isnull().sum()
# df.isnull().sum() / len(df) * 100
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64
