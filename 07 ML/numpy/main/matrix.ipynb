# %%
'''
type of matrix
1. square matrix
2. rectangular matrix
3. row matrix
4. column matrix
5. zero matrix
6. transpose of a matrix
7. swapaxes of a matrix
inverse of a matrix
power of a matrix
determinant of a matrix
6. diagonal matrix
8. identity matrix
7. scalar matrix
9. upper triangular matrix
10. lower triangular matrix
'''
