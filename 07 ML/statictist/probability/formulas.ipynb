# %%
'''
1. Basic Probability
P(A) = Number of Favorable Outcomes / Total Number of Outcomes

Example:
    A = [1, 2, 3, 4, 5, 6] 
    p(even) = 1/2
    p(odd) = 1/2


2. Complement Rule
P(A') = 1 - P(A)

Example:
    A = [1, 2, 3, 4, 5, 6] 
    p(even) = 1/2
    p(odd) = 1 - 1/2 = 1/2


3. Addition Rule
P(A ∪ B) = P(A) + P(B) - P(A ∩ B)
Example:

S = {1, 2, 3, 4, 5, 6}
n(S) = 6

A = {2, 4, 6}
n(A) = 3
B = {1, 2, 3}
n(B) = 3

P(A) = 3/6 = 1/2
P(B) = 3/6 = 1/2

A ∩ B = {2}
P(A ∩ B) = 1/6

P(A ∪ B) = P(A) + P(B) - P(A ∩ B)
          = 1/2 + 1/2 - 1/6
          = 1 - 1/6
          = 5/6

A ∪ B = {1, 2, 3, 4, 6}

Answer: P(A ∪ B) = 5/6    


If A and B are mutually exclusive:
P(A ∪ B) = P(A) + P(B)

4. Multiplication Rule
For any two events:
P(A ∩ B) = P(A) * P(B|A)

For independent events:
P(A ∩ B) = P(A) * P(B)

5. Conditional Probability
P(A|B) = P(A ∩ B) / P(B)

6. Bayes' Theorem
P(A|B) = [P(B|A) * P(A)] / P(B)

7. Total Probability Theorem
P(A) = P(A|B1)P(B1) + P(A|B2)P(B2) + ... + P(A|Bn)P(Bn)

8. Probability of At Least One Event
P(At least one) = 1 - P(None)

9. Probability of Exactly One Event
P(Exactly one) = P(A)P(B') + P(A')P(B)

10. Independent Events
P(A ∩ B) = P(A) * P(B)

11. Mutually Exclusive Events
P(A ∩ B) = 0

12. Complement of Union
P((A ∪ B)') = P(A' ∩ B')

13. Complement of Intersection
P((A ∩ B)') = P(A' ∪ B')

14. Factorial
n! = n * (n-1) * (n-2) * ... * 2 * 1
0! = 1

15. Permutation
nPr = n! / (n - r)!

16. Combination
nCr = n! / [r!(n - r)!]

17. Binomial Probability
P(X = x) = nCx * p^x * (1 - p)^(n - x)

18. Expected Value (Mean)
E(X) = Σ[x * P(x)]

19. Variance
Var(X) = E(X²) - (E(X))²

20. Standard Deviation
SD = √Var(X)

21. Odds in Favor
Odds = P(A) / (1 - P(A))

22. Odds Against
Odds = (1 - P(A)) / P(A)

23. Sample Space
P(S) = 1

24. Impossible Event
P(∅) = 0

25. Complement Identity
P(A) + P(A') = 1

26. Difference of Events
P(A - B) = P(A) - P(A ∩ B)

27. Three-Event Addition Rule
P(A ∪ B ∪ C) =
P(A) + P(B) + P(C)
- P(A ∩ B)
- P(B ∩ C)
- P(A ∩ C)
+ P(A ∩ B ∩ C)
'''
